# %% [markdown]
# # Trabajo Práctico: Construcción de una panorámica mediante SIFT
#
# ## Objetivo
#
# En este trabajo deberán utilizar técnicas de visión artificial para identificar las regiones comunes entre dos fotografías de una misma escena tomadas desde distintos puntos de vista.
#
# A partir de estas correspondencias se deberá calcular la homografía que permitirá transformar una imagen para alinearla con la otra y generar finalmente una imagen panorámica.
#
# ## Material disponible
#
# Se permite que trabajen con dos (o más, ¡se incentiva la creatividad en el ejercicio!) imágenes a su elección, siempre que ambas fotografías muestran parte de la misma escena, y sean tomadas desde posiciones ligeramente diferentes.
#
# ---
#
# ## Consigna 1 - Carga y visualización
#
# Cargue ambas imágenes utilizando `OpenCV`.
#
# Visualice las imágenes una al lado de la otra e identifique visualmente:
#
# * la región que comparten
# * las diferencias de perspectiva
# * los objetos presentes en ambas imágenes
#
# > Describa con sus propias palabras en un párrafo corto, sin entrar en detalles técnicos, estas observaciones.

# %%
# Escriba aquí su código

# %% [markdown]
# ## Consigna 2 - Detección de puntos de interés
#
# Utilice el algoritmo SIFT para detectar puntos de interés en ambas imágenes.
#
# Visualice los keypoints encontrados sobre cada fotografía.
#
# Analice:
#
# * ¿En qué zonas aparecen más puntos?
# * ¿Por qué SIFT evita regiones completamente uniformes?
# * Con respecto a la región compartida, ¿observa coincidencias entre los puntos encontrados?
#
# > Nuevamente describa estas respuestas con sus propias palabras y diagnostique si cree que los puntos serán suficientes para encontrar la homografía correspondiente. En caso de que crea que no, considere la aplicación de operaciones de preprocesamiento (aumento de contraste, resalte de bordes, etc.) antes de aplicar SIFT. Deje registrado el antes y el después del proceso realizado.

# %%
# Escriba aquí su código

# %% [markdown]
# ## Consigna 3 - Descripción y comparación de características
#
# Obtenga las correspondencias entre los descriptores SIFT de ambas imágenes.
#
# Aplique el criterio de Lowe (Ratio Test) para eliminar coincidencias ambiguas y visualice únicamente las correspondencias aceptadas.
#
# Analice:
#
# * ¿Todas las correspondencias son correctas?
# * ¿Por qué pueden aparecer emparejamientos erróneos?
#
# > Responda estas preguntas con sus observaciones e indique si opina que debe hacer alguna corrección en los pasos anteriores.

# %%
# Escriba aquí su código

# %% [markdown]
# ## Consigna 4 - Estimación de la homografía
#
# A partir de las correspondencias obtenidas:
#
# * extraiga las coordenadas de los puntos correspondientes;
# * utilice `cv2.findHomography()` junto con el método RANSAC para estimar la transformación entre ambas imágenes.
#
# > Indique:
# > * la matriz de homografía obtenida;
# > * la cantidad de correspondencias utilizadas;
# > * cuántas fueron consideradas inliers por RANSAC.
# > ¿Por qué no es conveniente calcular la homografía utilizando todas las correspondencias sin RANSAC?

# %%
# Escriba aquí su código

# %% [markdown]
# ## Consigna 5 - Transformación de perspectiva
#
# Utilice la homografía obtenida para transformar una de las imágenes mediante `cv2.warpPerspective()`. Superponga las imágenes para generar una fusión de ambas que se vea como una panorámica.
#
# > Visualice y comente el resultado.

# %%
# Escriba aquí su código

# %% [markdown]
# ## Consigna 6 - Análisis del resultado
#
# Responda brevemente:
#
# > ¿Qué papel cumple SIFT dentro del proceso?
# > ¿Por qué es necesario calcular una homografía?
# > ¿Qué ocurriría si las dos fotografías no mostraran una región en común?
# > ¿Cómo afecta la cantidad de correspondencias correctas a la calidad de la panorámica?
# > ¿Qué mejoras podrían incorporarse para obtener un resultado más profesional?
